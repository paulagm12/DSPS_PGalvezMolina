# %% [markdown]
# <a href="https://colab.research.google.com/github/paulagm12/DSPS_PGalvezMolina/blob/main/HW8_PGalvezMolina/FixGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Old graph

# %%
plt.scatter(twodproj[:,0], twodproj[:,1], color = 'blue', label = 'Default')
# plt.scatter(twodproj2[:,0], twodproj2[:,1], color = 'pink', label = 'P = 100')
# plt.scatter(twodproj3[:,0], twodproj3[:,1], color = 'purple', label = 'P = 5')
plt.scatter(twodproj4[:,0], twodproj4[:,1], color = 'yellow', label = 'EE = 5 \n P = 5')
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.legend()

# %% [markdown]
# ### **Fig. 1.** TSNE 2D projection kidpack data base. In orange the projection with an Early Exaggeration of 5 and perplexity of 5. In blue the same data but with the default paramenters (Early Exaggeration of 12 and Perplexity of 30.0).

# %% [markdown]
# New graph

# %%
plt.scatter(twodproj4[:,0], twodproj4[:,1], marker=".", color = 'orange', label = 'EE = 5 \n P = 5')
plt.scatter(twodproj[:,0], twodproj[:,1], marker=".",color = 'blue', label = 'Default')
# plt.scatter(twodproj2[:,0], twodproj2[:,1], color = 'pink', label = 'P = 100')
# plt.scatter(twodproj3[:,0], twodproj3[:,1], color = 'purple', label = 'P = 5')
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.legend()

# %% [markdown]
# ### **Fig. 2.** TSNE 2D projection kidpack data base. In orange the projection with an Early Exaggeration of 5 and perplexity of 5. In blue the same data but with the default paramenters (Early Exaggeration of 12 and Perplexity of 30.0).
